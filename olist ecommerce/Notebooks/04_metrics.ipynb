# %%
#import libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#read processed data
orders = pd.read_csv(r'C:\Users\Ayoub-PC\Desktop\Olist Analysis Project\Data\Processed\orders_cleaned.csv')
customers = pd.read_csv(r'C:\Users\Ayoub-PC\Desktop\Olist Analysis Project\Data\Processed\customers_cleaned.csv')
products = pd.read_csv(r'C:\Users\Ayoub-PC\Desktop\Olist Analysis Project\Data\Processed\products_cleaned.csv')
order_items = pd.read_csv(r'C:\Users\Ayoub-PC\Desktop\Olist Analysis Project\Data\Processed\order_items_cleaned.csv')
sellers = pd.read_csv(r'C:\Users\Ayoub-PC\Desktop\Olist Analysis Project\Data\Processed\sellers_cleaned.csv')
order_payments = pd.read_csv(r'C:\Users\Ayoub-PC\Desktop\Olist Analysis Project\Data\Processed\order_payments_cleaned.csv')
order_reviews = pd.read_csv(r'C:\Users\Ayoub-PC\Desktop\Olist Analysis Project\Data\Processed\order_reviews_cleaned.csv')
geolocations = pd.read_csv(r'C:\Users\Ayoub-PC\Desktop\Olist Analysis Project\Data\Processed\geolocations_cleaned.csv')
Translation = pd.read_csv(r'C:\Users\Ayoub-PC\Desktop\Olist Analysis Project\Data\Processed\Translation_cleaned.csv')

# %%
order_items['order_id'].nunique()
len(order_items)
# Out:
# 112650

# %%
order_items[['order_id', 'order_item_id']].duplicated().sum()
# Out:
# 0

# %%
from sqlalchemy import create_engine
engine = create_engine("postgresql://user:password@localhost:5433/olist_analytics")

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:zambatar@localhost:5433/olist_analytics"
)

# Test connection
with engine.connect() as conn:
    print("Connection successful")
# Out:
# Connection successful

# %%
#load data to staging schema in postgres
orders.to_sql(
    name="orders",
    con=engine,
    schema="staging",
    if_exists="replace",
    index=False
)
order_items.to_sql(
    name="order_items",
    con=engine,
    schema="staging",
    if_exists="replace",
    index=False
)
customers.to_sql(
    name="customers",
    con=engine,
    schema="staging",
    if_exists="replace",
    index=False
)
products.to_sql(
    name="products",
    con=engine,
    schema="staging",
    if_exists="replace",
    index=False
)
sellers.to_sql(
    name="sellers",
    con=engine,
    schema="staging",
    if_exists="replace",
    index=False
)
order_payments.to_sql(
    name="order_payments",
    con=engine,
    schema="staging",
    if_exists="replace",
    index=False
)
order_reviews.to_sql(
    name="order_reviews",
    con=engine,
    schema="staging",
    if_exists="replace",
    index=False
)
geolocations.to_sql(
    name="geolocations",
    con=engine,
    schema="staging",
    if_exists="replace",
    index=False
)
Translation.to_sql(
    name="translation",
    con=engine,
    schema="staging",
    if_exists="replace",
    index=False
)
# Out:
# ---------------------------------------------------------------------------
# PendingRollbackError                      Traceback (most recent call last)
# Cell In[7], line 37
#      23 products.to_sql(
#      24     name="products",
#      25     con=engine,
#    (...)     28     index=False
#      29 )
#      30 sellers.to_sql(
#      31     name="sellers",
#      32     con=engine,
#    (...)     35     index=False
#      36 )
# ---> 37 order_payments.to_sql(
#      38     name="order_payments",
#      39     con=engine,
#      40     schema="staging",
#      41     if_exists="replace",
#      42     index=False
#      43 )
#      44 order_reviews.to_sql(
#      45     name="order_reviews",
#      46     con=engine,
#    (...)     49     index=False
#      50 )
#      51 geolocations.to_sql(
#      52     name="geolocations",
#      53     con=engine,
#    (...)     56     index=False
#      57 )
#
# ...

# %%
# Out:
# 71
